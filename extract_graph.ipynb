# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

## Input data directory
data_dir = "cureus"
inputdirectory = Path(f"./data_input/{data_dir}")
## This is where the output csv files will be written
out_dir = data_dir
outputdirectory = Path(f"./data_output/{out_dir}")
# Out:
# /tmp/ipykernel_241/2069259742.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Load Documents

# %%
## Dir PDF Loader
# loader = PyPDFDirectoryLoader(inputdirectory)
## File Loader
# loader = PyPDFLoader("./data/MedicalDocuments/orf-path_health-n1.pdf")
loader = DirectoryLoader(inputdirectory, show_progress=True)
documents = loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=150,
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(documents)
print("Number of chunks = ", len(pages))
print(pages[3].page_content)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:02<00:00,  2.00s/it]
# Number of chunks =  23
# An extensive literature search was performed, and 56 articles published in peer-reviewed journals between 2005 and 2021 were selected and analyzed. The corresponding authors' experiential knowledge served as the foundation for the analysis.

# %%
from pprint import pprint
pprint(pages[3].page_content)
pprint(pages[3].metadata)
# Out:
# ('An extensive literature search was performed, and 56 articles published in '
#  'peer-reviewed journals between 2005 and 2021 were selected and analyzed. The '
#  "corresponding authors' experiential knowledge served as the foundation for "
#  'the analysis.')
# {'source': 'data_input/cureus/cureus-0015-00000040274.txt'}

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
from helpers.df_helpers import documents2Dataframe
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (23, 3)
#                                                 text  \
# 0  Abstract India’s health indicators have improv...
# 1  Categories: Public Health, Epidemiology/Public...
# 2  Introduction And Background India’s health ind...
# 3  An extensive literature search was performed, ...
# 4  Review Overview of the public and private heal...
#
#                                           source  \
# 0  data_input/cureus/cureus-0015-00000040274.txt
# 1  data_input/cureus/cureus-0015-00000040274.txt
# 2  data_input/cureus/cureus-0015-00000040274.txt
# 3  data_input/cureus/cureus-0015-00000040274.txt
# 4  data_input/cureus/cureus-0015-00000040274.txt
#
#                            chunk_id
# 0  e0d601e29a534695b0542aaa14dcda0c
# 1  85f522faf05a4e14bd8857fc9d3f3095
# 2  a8ba04c5dacd4801b13d24d720dbb050
# 3  344e8aa442984bb3b8944808ed4fc213
# 4  a55ae25b6c7a405a846d21efbde3b1ef

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
import ollama.client as ollama
model_name = "mistral-openorca:latest"
# ollama_client = ollama.Client()
print(ollama.heartbeat())
new_model = ollama.pull(model_name)
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
# Ollama is running
# pulling manifest
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566298560
# pulling 6504ba23a371 - Digest: sha256:6504ba23a37160de70db611212815c9aab171864d206b8c013b72fd0b16e19eb - Total: 4108927680 - Completed: 1566299524

# %%
concepts_list = df2Graph(df[0:2], model=model_name)
# Out:
# India faces significant challenges in terms of its health workforce density, with an estimated active density of doctors, nurses, and midwives per 10,000 persons at 5.0, 6.0, and 7.0, respectively, which are significantly lower than the World Health Organization (WHO) threshold of 44.5 for these professions. This shortage is particularly pronounced in rural areas and between the public and private sectors, with the latter's booming medical tourism industry and medical schools exacerbating the divide. To address this issue, the recently increased federal health budget presents an unprecedented opportunity to augment India's skilled health workforce and accelerate progress toward universal health coverage and sustainable development goals (SDGs).
#
# To achieve this, policies should focus on increasing the number of medical schools and training institutions, improving the quality of education and training, and incentivizing doctors and nurses to work in underserved areas. Additionally, measures should be taken to reduce the burden on public healthcare systems by promoting preventive care and primary healthcare, as well as investing in telemedicine and other digital health technologies to bridge the rural-urban divide.
#
# In conclusion, addressing India's health workforce challenges is crucial for achieving universal health coverage and SDGs. By implementing policies that increase the number of skilled health workers, improve the quality of education and training, and incentivize doctors and nurses to work in underserved areas, India can make significant progress towards these goals.
#
# ERROR ### Here is the buggy response:
# India faces significant challenges in terms of its health workforce density, with an estimated active density of doctors, nurses, and midwives per 10,000 persons at 5.0, 6.0, and 7.0, respectively, which are significantly lower than the World Health Organization (WHO) threshold of 44.5 for these professions. This shortage is particularly pronounced in rural areas and between the public and private sectors, with the latter's booming medical tourism industry and medical schools exacerbating the divide. To address this issue, the recently increased federal health budget presents an unprecedented opportunity to augment India's skilled health workforce and accelerate progress toward universal health coverage and sustainable development goals (SDGs).
#
# To achieve this, policies should focus on increasing the number of medical schools and training institutions, improving the quality of education and training, and incentivizing doctors and nurses to work in underserved areas. Additionally, measures should be taken to reduce the burden on public healthcare systems by promoting preventive care and primary healthcare, as well as investing in telemedicine and other digital health technologies to bridge the rural-urban divide.
#
# In conclusion, addressing India's health workforce challenges is crucial for achieving universal health coverage and SDGs. By implementing policies that increase the number of skilled health workers, improve the quality of education and training, and incentivize doctors and nurses to work in underserved areas, India can make significant progress towards these goals.
#
#
#
# Here is a potential outline for the research paper on the working conditions of auxiliary nurse midwives in India and their impact on the health sector:
#
# I. Introduction
# A. Background on the importance of auxiliary nurse midwives in India's healthcare system
# B. Overview of the challenges faced by auxiliary nurse midwives in India
# C. Research question: What are the working conditions of auxiliary nurse midwives in India and how do they impact the health sector?
#
# II. Literature Review
# A. Existing research on the working conditions of auxiliary nurse midwives in India
# B. Factors affecting their working conditions, such as staffing levels, training, and supervision
# C. Impact of poor working conditions on patient care and health outcomes
#
# III. Methodology
# A. Study design: Cross-sectional study conducted in multiple Indian states
# B. Sample size and selection: Purposive sampling of auxiliary nurse midwives from public and private facilities
# C. Data collection: Survey questionnaire administered to participants
#
# IV. Results
# A. Demographic characteristics of the respondents
# B. Working conditions of auxiliary nurse midwives, including staffing levels, training, and supervision
# C. Impact of working conditions on patient care and health outcomes
#
# V. Discussion
# A. Analysis of the results in relation to existing literature on working conditions of auxiliary nurse midwives
# B. Factors contributing to poor working conditions, such as inadequate staffing levels and lack of supervision
# C. Impact of poor working conditions on the health sector, including patient care and health outcomes
#
# VI. Conclusion
# A. Summary of the findings and their implications for the health sector
# B. Recommendations for improving the working conditions of auxiliary nurse midwives in India
# C. Future research directions
#
# VII. References
# A. List of sources cited in the paper, formatted according to the chosen citation style.
#
# ERROR ### Here is the buggy response:
# Here is a potential outline for the research paper on the working conditions of auxiliary nurse midwives in India and their impact on the health sector:
#
# I. Introduction
# A. Background on the importance of auxiliary nurse midwives in India's healthcare system
# B. Overview of the challenges faced by auxiliary nurse midwives in India
# C. Research question: What are the working conditions of auxiliary nurse midwives in India and how do they impact the health sector?
#
# II. Literature Review
# A. Existing research on the working conditions of auxiliary nurse midwives in India
# B. Factors affecting their working conditions, such as staffing levels, training, and supervision
# C. Impact of poor working conditions on patient care and health outcomes
#
# III. Methodology
# A. Study design: Cross-sectional study conducted in multiple Indian states
# B. Sample size and selection: Purposive sampling of auxiliary nurse midwives from public and private facilities
# C. Data collection: Survey questionnaire administered to participants
#
# IV. Results
# A. Demographic characteristics of the respondents
# B. Working conditions of auxiliary nurse midwives, including staffing levels, training, and supervision
# C. Impact of working conditions on patient care and health outcomes
#
# V. Discussion
# A. Analysis of the results in relation to existing literature on working conditions of auxiliary nurse midwives
# B. Factors contributing to poor working conditions, such as inadequate staffing levels and lack of supervision
# C. Impact of poor working conditions on the health sector, including patient care and health outcomes
#
# VI. Conclusion
# A. Summary of the findings and their implications for the health sector
# B. Recommendations for improving the working conditions of auxiliary nurse midwives in India
# C. Future research directions
#
# VII. References
# A. List of sources cited in the paper, formatted according to the chosen citation style.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 concepts_list = df2Graph(df[0:2], model='llama2:latest')
#
# File /code/helpers/df_helpers.py:61, in df2Graph(dataframe, model)
#      58 results = results.reset_index(drop=True)
#      60 ## Flatten the list of lists to one single list of entities.
# ---> 61 concept_list = np.concatenate(results).ravel().tolist()
#      62 return concept_list
#
# ValueError: need at least one array to concatenate

# %%
concepts_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 concepts_list
#
# NameError: name 'concepts_list' is not defined

# %%
## To regenerate the graph with LLM, set this to True
regenerate = True

if regenerate:
    concepts_list = df2Graph(df, model='zephyr:latest')
    dfg1 = graph2Df(concepts_list)
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(outputdirectory/"graph.csv", sep="|", index=False)
    df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
else:
    dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head()
# Out:
# [
#    {
#        "node_1": "India's health indicators",
#        "node_2": "peer nations' health indicators",
#        "edge": "India's health indicators lag behind those of its peer nations."
#    },
#    {
#        "node_1": "active health workers density",
#        "node_2": "WHO threshold for doctors, nurses, and midwives per 10,000 population",
#        "edge": "India's estimated active health workers density of doctors and nurses/midwives is much lower than the WHO threshold."
#    },
#    {
#        "node_1": "skilled health workforce",
#        "node_2": "universal health coverage and sustainable development goals (SDGs)",
#        "edge": "calls to urgently augment the skilled health workforce reinforce the central role human resources have in healthcare, which has evolved into a complex multifactorial issue."
#    },
#    {
#        "node_1": "skilled personnel",
#        "node_2": "achieving universal health coverage and its sustainable development goals (SDGs)",
#        "edge": "the paucity of skilled personnel must be addressed if India is to accelerate its progress toward achieving universal health coverage and its sustainable development goals (SDGs)."
#    },
#    {
#        "node_1": "federal health budget",
#        "node_2": "accelerating its progress toward achieving universal health coverage and its sustainable development goals (SDGs)",
#        "edge": "The recent increase in the federal health budget offers an unprecedented opportunity to do this."
#    },
#    {
#        "node_1": "public-private sector divide",
#        "node_2": "health system in India",
#        "edge": "Calls to urgently augment the skilled health workforce reinforce the central role human resources have in healthcare, which has evolved into a complex multifactorial issue."
#    },
#    {
#        "node_1": "private health sector systems",
#        "node_2": "growing divide between the public and the burgeoning private health sector systems",
#        "edge": "The growing divide between the public and the burgeoning private health sector systems."
#    },
#    {
#        "node_1": "booming medical tourism industry",
#        "node_2": "private health sector systems",
#        "edge": "with the latter's booming medical tourism industry"
#    },
#    {
#        "node_1": "newly minted National Medical Council",
#        "node_2": "recommending policies that would help India achieve its SDGs",
#        "edge": "to analyze along with the newly minted National Medical Council, to recommend policies that would help India achieve its SDGs."
#    }
# ]
# The study aims to examine the association between adverse working conditions and burnout syndrome among Auxiliary Nurse Midwives (ANMs) in India, following the implementation of human resource policies for ANMs in 2014 as part of the National Health Mission's health sector reform. The study will use secondary data from the National Sample Survey Organisation's (NSSO) 75th Round (2018) to investigate the prevalence of burnout syndrome and adverse working conditions among ANMs in India, as well as identify factors associated with burnout syndrome. This information will provide insights into the effectiveness of the human resource policies for ANMs and inform future policy decisions related to the health sector reform in India. The study will contribute to the fields of public health, epidemiology, and health policy by providing evidence on the relationship between working conditions and burnout syndrome among ANMs, a critical issue in the Indian healthcare system. Keywords: working conditions, Indian Public Health Standards, Auxiliary Nurse Midwives, human resource, health sector reform, India, health policy.
#
# ERROR ### Here is the buggy response:  The study aims to examine the association between adverse working conditions and burnout syndrome among Auxiliary Nurse Midwives (ANMs) in India, following the implementation of human resource policies for ANMs in 2014 as part of the National Health Mission's health sector reform. The study will use secondary data from the National Sample Survey Organisation's (NSSO) 75th Round (2018) to investigate the prevalence of burnout syndrome and adverse working conditions among ANMs in India, as well as identify factors associated with burnout syndrome. This information will provide insights into the effectiveness of the human resource policies for ANMs and inform future policy decisions related to the health sector reform in India. The study will contribute to the fields of public health, epidemiology, and health policy by providing evidence on the relationship between working conditions and burnout syndrome among ANMs, a critical issue in the Indian healthcare system. Keywords: working conditions, Indian Public Health Standards, Auxiliary Nurse Midwives, human resource, health sector reform, India, health policy.
#
#
# The paper "Healthcare Workforce Development in India" discusses the shortage of skilled healthcare personnel in India, which is a multifactorial issue that requires immediate attention. The country's health indicators have improved in recent times but still lag behind those of its peer nations, with an estimated density of active health workers much lower than WHO recommended thresholds. This issue is compounded by disparities between inter-state, urban-rural, and public-private sectors.
#
# The authors provide an overview of the public and private healthcare sectors in India, highlighting their divergent strategies due to the growing divide between them. The private sector now has a booming medical tourism industry and a burgeoning number of medical schools. They identify opportunities available within the newly created National Medical Council and the recent increase in the federal health budget.
#
# To address the paucity of quality healthcare personnel, the authors recommend creating transparent governance, strengthening health infrastructure, upskilling the existing workforce, and creating partnerships with the private sector, which is much larger than the public sector. The READ approach, a systematic approach for document analysis in health policy research, is used to analyze the available data.
#
# Overall, the paper emphasizes the need for urgent action to address the shortage of skilled healthcare personnel in India, as it hampers the country's progress towards achieving universal health coverage and its sustainable development goals. The authors suggest that a multi-pronged approach is required to overcome this multifactorial issue.
#
# ERROR ### Here is the buggy response:  The paper "Healthcare Workforce Development in India" discusses the shortage of skilled healthcare personnel in India, which is a multifactorial issue that requires immediate attention. The country's health indicators have improved in recent times but still lag behind those of its peer nations, with an estimated density of active health workers much lower than WHO recommended thresholds. This issue is compounded by disparities between inter-state, urban-rural, and public-private sectors.
#
# The authors provide an overview of the public and private healthcare sectors in India, highlighting their divergent strategies due to the growing divide between them. The private sector now has a booming medical tourism industry and a burgeoning number of medical schools. They identify opportunities available within the newly created National Medical Council and the recent increase in the federal health budget.
#
# To address the paucity of quality healthcare personnel, the authors recommend creating transparent governance, strengthening health infrastructure, upskilling the existing workforce, and creating partnerships with the private sector, which is much larger than the public sector. The READ approach, a systematic approach for document analysis in health policy research, is used to analyze the available data.
#
# Overall, the paper emphasizes the need for urgent action to address the shortage of skilled healthcare personnel in India, as it hampers the country's progress towards achieving universal health coverage and its sustainable development goals. The authors suggest that a multi-pronged approach is required to overcome this multifactorial issue.
#
#
# Title: "Evaluation of the Efficacy and Safety Profile of Immune Checkpoint Inhibitors in Metastatic Melanoma Patients with Brain Metastases"
#
# Abstract:
#
# Background: The management of melanoma with brain metastases (BM) has significantly evolved over the past decade, mainly due to the emergence of immune checkpoint inhibitors (ICIs). The aim of this systematic review was to analyze the efficacy and safety profile of ICIs in patients with metastatic melanoma and BM.
#
# Methods: A comprehensive literature search was conducted using PubMed, Embase, and Cochrane databases from 2005 to 2021. Eligible studies included randomized controlled trials (RCTs), observational studies, case series, and phase III clinical trials evaluating the efficacy and safety of ICIs in patients with metastatic melanoma and BM. Articles were assessed based on inclusion criteria and assessed for quality using the Cochrane Risk of Bias tool. The analysis was performed by two independent reviewers.
#
# Results: A total of 56 articles were selected for this systematic review. Most studies reported a clinical benefit rate (CBR) ranging from 21% to 47%. Complete responses (CRs) and partial responses (PRs) ranged from 0% to 8% and 11% to 34%, respectively. The median progression-free survival (PFS) and overall survival (OS) for patients treated with ICIs were 2.6 months and 9.7 months, respectively.
#
# In terms of safety, the most commonly reported adverse events (AEs) were fatigue, pyrexia, diarrhea, and pruritus. Grades 3-4 AEs occurred in 14% to 20% of patients, with pneumonitis being the most common grade 3-4 AE reported (range: 1% to 7%). Cerebral toxicities were reported in 1% to 16% of patients, with encephalitis and cerebellitis being the most common.
#
# Conclusions: The findings from this systematic review suggest that ICIs demonstrate a clinical benefit in patients with metastatic melanoma and BM. However, further research is needed to determine the optimal timing and sequencing of ICI therapy in patients with BM, as well as to develop strategies for managing cerebral toxicities.
#
# Keywords: Melanoma, brain metastases, immune checkpoint inhibitors, efficacy, safety, systematic review
#
# ERROR ### Here is the buggy response:  Title: "Evaluation of the Efficacy and Safety Profile of Immune Checkpoint Inhibitors in Metastatic Melanoma Patients with Brain Metastases"
#
# Abstract:
#
# Background: The management of melanoma with brain metastases (BM) has significantly evolved over the past decade, mainly due to the emergence of immune checkpoint inhibitors (ICIs). The aim of this systematic review was to analyze the efficacy and safety profile of ICIs in patients with metastatic melanoma and BM.
#
# Methods: A comprehensive literature search was conducted using PubMed, Embase, and Cochrane databases from 2005 to 2021. Eligible studies included randomized controlled trials (RCTs), observational studies, case series, and phase III clinical trials evaluating the efficacy and safety of ICIs in patients with metastatic melanoma and BM. Articles were assessed based on inclusion criteria and assessed for quality using the Cochrane Risk of Bias tool. The analysis was performed by two independent reviewers.
#
# Results: A total of 56 articles were selected for this systematic review. Most studies reported a clinical benefit rate (CBR) ranging from 21% to 47%. Complete responses (CRs) and partial responses (PRs) ranged from 0% to 8% and 11% to 34%, respectively. The median progression-free survival (PFS) and overall survival (OS) for patients treated with ICIs were 2.6 months and 9.7 months, respectively.
#
# In terms of safety, the most commonly reported adverse events (AEs) were fatigue, pyrexia, diarrhea, and pruritus. Grades 3-4 AEs occurred in 14% to 20% of patients, with pneumonitis being the most common grade 3-4 AE reported (range: 1% to 7%). Cerebral toxicities were reported in 1% to 16% of patients, with encephalitis and cerebellitis being the most common.
#
# Conclusions: The findings from this systematic review suggest that ICIs demonstrate a clinical benefit in patients with metastatic melanoma and BM. However, further research is needed to determine the optimal timing and sequencing of ICI therapy in patients with BM, as well as to develop strategies for managing cerebral toxicities.
#
# Keywords: Melanoma, brain metastases, immune checkpoint inhibitors, efficacy, safety, systematic review
#
#
# The public health sector in India is underfunded with only 1.28% of the GDP allocated to it, resulting in a healthcare expenditure of $2.70 per citizen per year. This has led to a shortage of resources, with India having only 0.7 public hospital beds per 100,000 people and 0.576 physicians per 1,000 population in 2000 (compared to the recommended doctor-to-population ratio of 1:1,000). The government's National Health Mission has failed to significantly improve healthcare indicators due to a lack of focus on quality care. As a result, the private health sector, which consumes 5.1% of the GDP and is financed by Out-Of-Pocket expenditure, has become the dominant provider of healthcare. This sector spans from high-quality, internationally accredited facilities like Narayana Health to individual informal provider clinics staffed by solo practitioners without formal medical qualifications or registration. Only 37% of the population had any health insurance coverage in 2018.
#
# ERROR ### Here is the buggy response:  The public health sector in India is underfunded with only 1.28% of the GDP allocated to it, resulting in a healthcare expenditure of $2.70 per citizen per year. This has led to a shortage of resources, with India having only 0.7 public hospital beds per 100,000 people and 0.576 physicians per 1,000 population in 2000 (compared to the recommended doctor-to-population ratio of 1:1,000). The government's National Health Mission has failed to significantly improve healthcare indicators due to a lack of focus on quality care. As a result, the private health sector, which consumes 5.1% of the GDP and is financed by Out-Of-Pocket expenditure, has become the dominant provider of healthcare. This sector spans from high-quality, internationally accredited facilities like Narayana Health to individual informal provider clinics staffed by solo practitioners without formal medical qualifications or registration. Only 37% of the population had any health insurance coverage in 2018.
#
#
# In response to the growing burden of non-communicable diseases (NCDs) in India, the National Programme for Prevention and Control of Cancer, Diabetes, Cardiovascular Diseases and Stroke (NPCDCS) was launched in 2010. The programme aims to provide affordable screening, early diagnosis, and treatment services for NCDs through a public-private partnership model. As part of the NPCDCS initiative, private healthcare providers have been engaged by the National Health Mission (NHM) under the umbrella scheme "Health and Wellness Centres (HWCs)" to provide NCD screening and management services at primary healthcare level. This collaboration between the public health sector and private healthcare providers has resulted in significant improvements in NCD screening, diagnosis, and management outcomes in several states, including Tamil Nadu, Karnataka, and Maharashtra. The data from the NPCDCS program indicates that 4.5 million individuals have been screened for cancer, diabetes, and hypertension, resulting in early detection and treatment of many cases. Additionally, over 13 million individuals have received health education on NCD prevention through this initiative. Overall, the engagement of private healthcare providers has strengthened the delivery of NCD services through the public healthcare system in India.
#
# The National Rural Health Mission (NRHM), later renamed as National Health Mission (NHM) in 2013, has played a pivotal role in addressing the challenges posed by the dual burden of communicable and non-communicable diseases in rural areas through its strategies. The NRHM/NHM's approaches for addressing health challenges include communitization, flexible financing, improved management through capacity building, monitoring progress against standards, and innovations in human resource management. These efforts have led to the creation of multiple new cadres to provide primary healthcare services and accelerate the pace toward universal health coverage. The NHM has also focused on strengthening district-level planning, implementation, and coordination mechanisms for health programs, enhancing community engagement and ownership through participatory decision-making processes, and improving accountability through regular monitoring and evaluation. These strategies have contributed significantly to improving health outcomes in rural areas, as evidenced by the reduction in infant mortality rate, maternal mortality ratio, and under-five mortality rate in several states.
#
# The informal healthcare sector, consisting of traditional healers and quacks, has a significant presence in India's rural areas, where it often serves as the first point of care for the population. According to estimates, there are approximately 1.5 million quacks and 700,000 traditional birth attendants (TBAs) in India. While these providers have been criticized for their poor-quality services, they are a crucial source of healthcare for the rural population, particularly for women and children. The National Rural Health Mission recognizes the importance of these informal providers and has adopted strategies to integrate them into the public health system. For example, TBAs are trained and supported by the NHM to provide safe deliveries and referral services to nearby health facilities. Quacks have also been engaged through initiatives like Janani Suraksha Yojana (JSY) to facilitate institutional deliveries. These efforts have led to an increase in facility-based deliveries, contributing significantly to reducing maternal and neonatal mortality rates in rural areas.
#
# In conclusion, the engagement of private healthcare providers, strengthening of the public health system through initiatives like NPCDCS and the NRHM/NHM, and integration of informal healthcare providers into the public health system have contributed significantly to improving health outcomes in India, particularly in rural areas. These collaborative efforts have resulted in improved access to essential healthcare services, enhanced quality of care, and increased utilization of health facilities. The data presented in this policy brief highlight the successes and challenges of these initiatives and suggest directions for future research and action. It is crucial that these collaborations continue to be strengthened and scaled up to address the growing burden of diseases in India, particularly NCDs and mental health disorders, and promote universal health coverage.
#
# ERROR ### Here is the buggy response:  In response to the growing burden of non-communicable diseases (NCDs) in India, the National Programme for Prevention and Control of Cancer, Diabetes, Cardiovascular Diseases and Stroke (NPCDCS) was launched in 2010. The programme aims to provide affordable screening, early diagnosis, and treatment services for NCDs through a public-private partnership model. As part of the NPCDCS initiative, private healthcare providers have been engaged by the National Health Mission (NHM) under the umbrella scheme "Health and Wellness Centres (HWCs)" to provide NCD screening and management services at primary healthcare level. This collaboration between the public health sector and private healthcare providers has resulted in significant improvements in NCD screening, diagnosis, and management outcomes in several states, including Tamil Nadu, Karnataka, and Maharashtra. The data from the NPCDCS program indicates that 4.5 million individuals have been screened for cancer, diabetes, and hypertension, resulting in early detection and treatment of many cases. Additionally, over 13 million individuals have received health education on NCD prevention through this initiative. Overall, the engagement of private healthcare providers has strengthened the delivery of NCD services through the public healthcare system in India.
#
# The National Rural Health Mission (NRHM), later renamed as National Health Mission (NHM) in 2013, has played a pivotal role in addressing the challenges posed by the dual burden of communicable and non-communicable diseases in rural areas through its strategies. The NRHM/NHM's approaches for addressing health challenges include communitization, flexible financing, improved management through capacity building, monitoring progress against standards, and innovations in human resource management. These efforts have led to the creation of multiple new cadres to provide primary healthcare services and accelerate the pace toward universal health coverage. The NHM has also focused on strengthening district-level planning, implementation, and coordination mechanisms for health programs, enhancing community engagement and ownership through participatory decision-making processes, and improving accountability through regular monitoring and evaluation. These strategies have contributed significantly to improving health outcomes in rural areas, as evidenced by the reduction in infant mortality rate, maternal mortality ratio, and under-five mortality rate in several states.
#
# The informal healthcare sector, consisting of traditional healers and quacks, has a significant presence in India's rural areas, where it often serves as the first point of care for the population. According to estimates, there are approximately 1.5 million quacks and 700,000 traditional birth attendants (TBAs) in India. While these providers have been criticized for their poor-quality services, they are a crucial source of healthcare for the rural population, particularly for women and children. The National Rural Health Mission recognizes the importance of these informal providers and has adopted strategies to integrate them into the public health system. For example, TBAs are trained and supported by the NHM to provide safe deliveries and referral services to nearby health facilities. Quacks have also been engaged through initiatives like Janani Suraksha Yojana (JSY) to facilitate institutional deliveries. These efforts have led to an increase in facility-based deliveries, contributing significantly to reducing maternal and neonatal mortality rates in rural areas.
#
# In conclusion, the engagement of private healthcare providers, strengthening of the public health system through initiatives like NPCDCS and the NRHM/NHM, and integration of informal healthcare providers into the public health system have contributed significantly to improving health outcomes in India, particularly in rural areas. These collaborative efforts have resulted in improved access to essential healthcare services, enhanced quality of care, and increased utilization of health facilities. The data presented in this policy brief highlight the successes and challenges of these initiatives and suggest directions for future research and action. It is crucial that these collaborations continue to be strengthened and scaled up to address the growing burden of diseases in India, particularly NCDs and mental health disorders, and promote universal health coverage.
#
#
# A report by the World Health Organization (WHO) has found that India has made significant progress in reducing maternal mortality ratios (MMRs), with a decline from 305 deaths per 100,00 live births in 2005-06 to 167 in 2011-13. This reduction is largely attributed to improvements in accessibility, availability, and affordability of maternal health care services, particularly for the poorest and rural populations. The study also highlights the importance of government spending on healthcare and community-based interventions, such as Accredited Social Health Activists (ASHAs). However, concerns have been raised regarding the task shifting from Auxiliary Nurse Midwives (ANMs) to ASHAs, with some evaluations showing few overall positive findings. ANMs are government employees who receive more training and a salary, while ASHAs are treated as private contractors receiving payment based on work performed.
#
# ERROR ### Here is the buggy response:  A report by the World Health Organization (WHO) has found that India has made significant progress in reducing maternal mortality ratios (MMRs), with a decline from 305 deaths per 100,00 live births in 2005-06 to 167 in 2011-13. This reduction is largely attributed to improvements in accessibility, availability, and affordability of maternal health care services, particularly for the poorest and rural populations. The study also highlights the importance of government spending on healthcare and community-based interventions, such as Accredited Social Health Activists (ASHAs). However, concerns have been raised regarding the task shifting from Auxiliary Nurse Midwives (ANMs) to ASHAs, with some evaluations showing few overall positive findings. ANMs are government employees who receive more training and a salary, while ASHAs are treated as private contractors receiving payment based on work performed.

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#                              node_1          node_2  \
# 2827  world-class health facilities  nhm strategies
# 2828  world-class health facilities     rural areas
# 2829  world-class health facilities    social norms
# 2830  world-class health facilities     urban areas
# 2831  world-class health facilities     urban slums
#
#                                                chunk_id  count  \
# 2827  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...     10
# 2828  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...      2
# 2829  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...      2
# 2830  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...      2
# 2831  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...      2
#
#                       edge
# 2827  contextual proximity
# 2828  contextual proximity
# 2829  contextual proximity
# 2830  contextual proximity
# 2831  contextual proximity

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                             node_1  \
# 0                      56 articles
# 1                             [54]
# 2                             [55]
# 3                  a bad situation
# 4            a worrisome new trend
# ..                             ...
# 753  world-class health facilities
# 754  world-class health facilities
# 755  world-class health facilities
# 756  world-class health facilities
# 757  world-class health facilities
#
#                                                node_2  \
# 0                         extensive literature search
# 1    increasing violence against healthcare personnel
# 2    increasing violence against healthcare personnel
# 3    increasing violence against healthcare personnel
# 4    increasing violence against healthcare personnel
# ..                                                ...
# 753                                    nhm strategies
# 754                                       rural areas
# 755                                      social norms
# 756                                       urban areas
# 757                                       urban slums
#
#                                               chunk_id                  edge  \
# 0    d7a3e5085c7f4de4bc28fb0bd9cb0a94,d7a3e5085c7f4...  contextual proximity
# 1    640835e2521045a395ab6465cc1ba4ca,640835e252104...  contextual proximity
# 2    640835e2521045a395ab6465cc1ba4ca,640835e252104...  contextual proximity
# 3    640835e2521045a395ab6465cc1ba4ca,640835e252104...  contextual proximity
# 4    640835e2521045a395ab6465cc1ba4ca,640835e252104...  contextual proximity
# ..                                                 ...                   ...
# 753  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...  contextual proximity
# 754  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...  contextual proximity
# 755  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...  contextual proximity
# 756  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...  contextual proximity
# 757  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...  contextual proximity
#
#      count
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
# ..     ...
# 753     10
# 754      2
# 755      2
# 756      2
# 757      2
#
# [758 rows x 5 columns]

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (215,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  17
# [['56 articles', 'analysis', "corresponding authors' experiential knowledge", 'extensive literature search', 'peer-reviewed journals'], ['[54]', '[55]', 'a bad situation', 'a worrisome new trend', 'adequately compensated', 'can reverse the situation', 'defensive medicine practices', 'increasing violence against healthcare personnel', 'intense focus on specialization', 'low physician-to-patient ratio', 'overwhelmed physicians', 'primary care physicians', 'private marketplace', 'protect themselves by ordering unnecessary tests and procedures', 'results in delays in attending patients', 'set in', 'tempted to take on more patients than they can reasonably serve', 'thoughtful approach to government planning', 'underpaid physicians', 'unethical practices by pharmaceutical companies', 'will not be able to solve this'], ['accredit health facilities', 'enforcement of existing rules', 'health insurance scheme for central government employees', 'health system standardization', 'implementation of land allocation conditions', 'medical tourism hub', 'new rules for reasonable costs and cap profit margins', 'private health sector regulation', 'private health sector utilization'], ['accurate data about the quantity and geospatial location of its manpower', "central government's leadership in the fight for better health for all indians", 'live register for health personnel and infrastructure'], ['adoption', 'affordable, accessible, quality care', 'clinical and social skills', 'corporate houses', 'deeper structural problems', 'doctor-to-population ratio', 'erratic posting of personnel', 'evaluations', 'for-profit private health sector', 'government', 'government-funded health sector', 'health infrastructure', 'health personnel', 'health system', 'implementation', 'individualized mentoring', 'medical tourism', 'narayana health', 'national health mission (nhm)', 'non-hierarchical work environment', 'online training', 'out-of-pocket (oop) expenditure', 'out-of-pocket expenditure', 'overarching', 'patients', 'personnel retention', 'physicians', 'policy', 'primary care', 'private health sector', 'providing ongoing training', 'public and private health sectors', 'public health sector', 'public hospital beds', 'quality care', 'quality of care', 'quantum of services provided', 'recommendations made here', 'regulation', 'retaining', 'service provision', 'services they have been trained for', 'sourcing health personnel', 'strengthening', 'tier ii and iii cities', 'training', 'training initiative', 'transparency', 'transparency in creating training schedules', 'uniform standards', 'unmet demand for healthcare services', 'upgrading skills of nurses', 'vulnerable populations', 'well-equipped personnel', 'work environment', "world health organization's recommended"], ['ai-embedded logarithms now diagnose covid-19 disease from chest x-rays and ct scans', 'covid-19 pandemic catalyzing process and enabling delivery of healthcare', 'doctors can now perform an ophthalmic fundal examination online', 'drones being used to deliver medicines to communities', 'expanding application of technology to other portfolios within the health sector', 'innovations in digital technology supporting delivery of vital healthcare in high-income countries', 'manufacturing protective equipment locally using 3d printing', 'remote orthopedic examinations being used successfully', 'telemedicine for consultations with healthcare providers', 'uptake of telemedicine during covid-19 pandemic'], ['allocated budget to healthcare', 'ashas', 'ayush doctors', 'ayushman bharat', 'cadres', 'communities', 'communitization', 'contractors', 'contracts', 'contractual employees', 'contractual personnel', 'delayed', 'demotivation', 'doctors', 'economic norms', 'epidemiology/public health', 'financially protected from catastrophic health expenses', 'flexible financing', 'gdp', 'government of india', 'health policy', 'health sector reform', 'healthcare facilities', 'high-income countries', 'improved managem ...

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                               node    color  group
# 0                                      56 articles  #db5f57      1
# 1                                         analysis  #db5f57      1
# 2    corresponding authors' experiential knowledge  #db5f57      1
# 3                      extensive literature search  #db5f57      1
# 4                           peer-reviewed journals  #db5f57      1
# ..                                             ...      ...    ...
# 210                rural medical assistants (rmas)  #ccdb57     15
# 211                                 limited uptake  #dbbc57     16
# 212             national health protection mission  #dbbc57     16
# 213                  private health sector systems  #57bcdb     17
# 214                                         public  #57bcdb     17
#
# [215 rows x 3 columns]

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# ./docs/index.html
